# %%
# !wget --no-check-certificate \
    https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
    -O /tmp/Chessman-image-dataset.zip
# Out:
# --2022-09-22 09:35:51--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2022-09-22 09:35:51--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   151MB/s    in 0.4s
#
# 2022-09-22 09:35:56 (151 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Rook', 'Bishop', 'Knight', 'Queen', 'Pawn', 'King']

# %%
# !ls /tmp/Chessman-image-dataset/Chess
# Out:
# Bishop	King  Knight  Pawn  Queen  Rook

# %%
# dataset ini berukuran sangat kecil sehingga performa dari model mungkin tidak akan terlalu baik. menggunakan augmentasi gambar untuk mengatasi masalah ini
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106

# %%
#Kita dapat melihat contoh dari sebuah gambar pada dataset dengan menjalankan kode di bawah
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
# impor ImageDataGenerator dan aplikasikan augmentasi gambar pada dataset kita.
from tensorflow.keras.preprocessing.image import ImageDataGenerator
 
 
train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.1) # set validation split

# %%
""""dengan menggunakan parameter validation_split yang disebut pada paragraf sebelumnya. 
Dengan parameter tersebut, kita hanya cukup memberi tahu ImageDataGenerator
 mana data untuk training dan mana data untuk testing dengan menambahkan parameter subset dengan nilai training atau validation."""
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training') # set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
#Selanjutnya, kita buat arsitektur dari model kita. Untuk model ini kita menggunakan 3 lapis convolution dan 2 hidden layer dengan 512 dan 256 buah unit perseptron
import tensorflow as tf
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')  
])

# %%
#Setelah arsitektur dibuat, tentukan optimizer dan loss yang akan digunakan model
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
#Terakhir, panggil fungsi fit untuk melatih model kita. 
history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 21s - loss: 1.8495 - accuracy: 0.1503 - val_loss: 1.7855 - val_accuracy: 0.1923 - 21s/epoch - 338ms/step
# Epoch 2/50
# 63/63 - 9s - loss: 1.7909 - accuracy: 0.1864 - val_loss: 1.7828 - val_accuracy: 0.1731 - 9s/epoch - 141ms/step
# Epoch 3/50
# 63/63 - 9s - loss: 1.7788 - accuracy: 0.2265 - val_loss: 1.7870 - val_accuracy: 0.1731 - 9s/epoch - 142ms/step
# Epoch 4/50
# 63/63 - 10s - loss: 1.7644 - accuracy: 0.2385 - val_loss: 1.8336 - val_accuracy: 0.1923 - 10s/epoch - 155ms/step
# Epoch 5/50
# 63/63 - 9s - loss: 1.7385 - accuracy: 0.2465 - val_loss: 1.7347 - val_accuracy: 0.2308 - 9s/epoch - 140ms/step
# Epoch 6/50
# 63/63 - 9s - loss: 1.7113 - accuracy: 0.2465 - val_loss: 1.7274 - val_accuracy: 0.3269 - 9s/epoch - 143ms/step
# Epoch 7/50
# 63/63 - 9s - loss: 1.6578 - accuracy: 0.3226 - val_loss: 1.6282 - val_accuracy: 0.3077 - 9s/epoch - 143ms/step
# Epoch 8/50
# 63/63 - 9s - loss: 1.6309 - accuracy: 0.3487 - val_loss: 1.7063 - val_accuracy: 0.3269 - 9s/epoch - 143ms/step
# Epoch 9/50
# 63/63 - 9s - loss: 1.5554 - accuracy: 0.3447 - val_loss: 1.6157 - val_accuracy: 0.3269 - 9s/epoch - 142ms/step
# Epoch 10/50
# 63/63 - 9s - loss: 1.5306 - accuracy: 0.3627 - val_loss: 1.6281 - val_accuracy: 0.4038 - 9s/epoch - 142ms/step
# Epoch 11/50
# 63/63 - 9s - loss: 1.4825 - accuracy: 0.4188 - val_loss: 1.5691 - val_accuracy: 0.2885 - 9s/epoch - 143ms/step
# Epoch 12/50
# 63/63 - 9s - loss: 1.4189 - accuracy: 0.4429 - val_loss: 1.5610 - val_accuracy: 0.3654 - 9s/epoch - 141ms/step
# Epoch 13/50
# 63/63 - 9s - loss: 1.3817 - accuracy: 0.4389 - val_loss: 1.5493 - val_accuracy: 0.4231 - 9s/epoch - 141ms/step
# Epoch 14/50
# 63/63 - 9s - loss: 1.3315 - accuracy: 0.4749 - val_loss: 1.6564 - val_accuracy: 0.3846 - 9s/epoch - 142ms/step
# Epoch 15/50
# 63/63 - 10s - loss: 1.2863 - accuracy: 0.5531 - val_loss: 1.7223 - val_accuracy: 0.3462 - 10s/epoch - 157ms/step
# Epoch 16/50
# 63/63 - 9s - loss: 1.2462 - accuracy: 0.5291 - val_loss: 1.5963 - val_accuracy: 0.4231 - 9s/epoch - 143ms/step
# Epoch 17/50
# 63/63 - 9s - loss: 1.2326 - accuracy: 0.5110 - val_loss: 1.5318 - val_accuracy: 0.3846 - 9s/epoch - 143ms/step
# Epoch 18/50
# 63/63 - 9s - loss: 1.1706 - accuracy: 0.5491 - val_loss: 1.4467 - val_accuracy: 0.4231 - 9s/epoch - 142ms/step
# Epoch 19/50
# 63/63 - 9s - loss: 1.1585 - accuracy: 0.5251 - val_loss: 1.5150 - val_accuracy: 0.4423 - 9s/epoch - 142ms/step
# Epoch 20/50
# 63/63 - 9s - loss: 1.0587 - accuracy: 0.5892 - val_loss: 1.4996 - val_accuracy: 0.4423 - 9s/epoch - 141ms/step
# Epoch 21/50
# 63/63 - 9s - loss: 1.0649 - accuracy: 0.5832 - val_loss: 1.5691 - val_accuracy: 0.3846 - 9s/epoch - 140ms/step
# Epoch 22/50
# 63/63 - 9s - loss: 1.0799 - accuracy: 0.5912 - val_loss: 1.5075 - val_accuracy: 0.3654 - 9s/epoch - 141ms/step
# Epoch 23/50
# 63/63 - 9s - loss: 0.9504 - accuracy: 0.6693 - val_loss: 1.5488 - val_accuracy: 0.4231 - 9s/epoch - 140ms/step
# Epoch 24/50
# 63/63 - 9s - loss: 0.9388 - accuracy: 0.6613 - val_loss: 1.5093 - val_accuracy: 0.4231 - 9s/epoch - 141ms/step
# Epoch 25/50
# 63/63 - 9s - loss: 0.8635 - accuracy: 0.6693 - val_loss: 1.4311 - val_accuracy: 0.4423 - 9s/epoch - 141ms/step
# Epoch 26/50
# 63/63 - 9s - loss: 0.9219 - accuracy: 0.6733 - val_loss: 1.6229 - val_accuracy: 0.4231 - 9s/epoch - 140ms/step
# Epoch 27/50
# 63/63 - 9s - loss: 0.8528 - accuracy: 0.6854 - val_loss: 1.6677 - val_accuracy: 0.3654 - 9s/epoch - 140ms/step
# Epoch 28/50
# 63/63 - 9s - loss: 0.7927 - accuracy: 0.7014 - val_loss: 1.6304 - val_accuracy: 0.4423 - 9s/epoch - 140ms/step
# Epoch 29/50
# 63/63 - 9s - loss: 0.8829 - accuracy: 0.7054 - val_loss: 1.4687 - val_accuracy: 0.4808 - 9s/epoch - 141ms/step
# Epoch 30/50
# 63/63 - 9s - loss: 0.7799 - accuracy: 0.7315 - val_loss: 1.6103 - val_accuracy: 0.4231 - 9s/epoch - 140ms/step
# Epoch 31/50
# 63/63 - 9s - loss: 0.7227 - accuracy: 0.7154 - val_loss: 1.6900 - val_accuracy: 0.4423 - 9s/epoch - 141ms/step
# Epoch 32/50
# 63/63 - 9s - loss: 0.7122 - accuracy: 0.7335 - val_loss: 1.5656 - val_accuracy: 0.4615 - 9s/epoch - 140ms/step
# Epoch 33/50
# 63/63 - 9s - loss: 0.8052 - accuracy: 0.7034 - val_loss: 1.4474 - val_accuracy: 0.4808 - 9s/epoch - 140ms/step
# Epoch 34/50
# 63/63 - 9s - loss: 0.6215 - accuracy: 0.7615 - val_loss: 1.8366 - val_accuracy: 0.3846 - 9s/epoch - 141ms/step
# Epoch 35/50
# 63/63 - 9s - loss: 0.6454 - accuracy: 0.7575 - val_loss: 1.3772 - val_accuracy: 0.4615 - 9s/epoch - 142ms/step
# Epoch 36/50
# 63/63 - 10s - loss: 0.6493 - accuracy: 0.7735 - val_loss: 1.7549 - val_accuracy: 0.2500 - 10s/epoch - 153ms/step
# Epoch 37/50
# 63/63 - 9s - loss: 0.6134 - accuracy: 0.7916 - val_loss: 1.4512 - val_accuracy: 0.4615 - 9s/epoch - 139ms/step
# Epoch 38/50
# 63/63 - 9s - loss: 0.5953 - accuracy: 0.7796 - val_loss: 1.6226 - val_accuracy: 0.4615 - 9s/epoch - 140ms/step
# Epoch 39/50
# 63/63 - 9s - loss: 0.5219 - accuracy: 0.8297 - val_loss: 1.8397 - val_accuracy: 0.4038 - 9s/epoch - 139ms/step
# Epoch 40/50
# 63/63 - 9s - loss: 0.5490 - accuracy: 0.8036 - val_loss: 1.7111 - val_accuracy: 0.4423 - 9s/epoch - 139ms/step
# Epoch 41/50
# 63/63 - 9s - loss: 0.4976 - accuracy: 0.8136 - val_loss: 1.7402 - val_accuracy: 0.4615 - 9s/epoch - 142ms/step
# Epoch 42/50
# 63/63 - 9s - loss: 0.6089 - accuracy: 0.7776 - val_loss: 1.8842 - val_accuracy: 0.4423 - 9s/epoch - 142ms/step
# Epoch 43/50
# 63/63 - 10s - loss: 0.5180 - accuracy: 0.8176 - val_loss: 1.8922 - val_accuracy: 0.4423 - 10s/epoch - 152ms/step
# Epoch 44/50
# 63/63 - 9s - loss: 0.4993 - accuracy: 0.8196 - val_loss: 1.4388 - val_accuracy: 0.5385 - 9s/epoch - 139ms/step
# Epoch 45/50
# 63/63 - 9s - loss: 0.5698 - accuracy: 0.7856 - val_loss: 2.1400 - val_accuracy: 0.3846 - 9s/epoch - 141ms/step
# Epoch 46/50
# 63/63 - 9s - loss: 0.4372 - accuracy: 0.8497 - val_loss: 2.0954 - val_accuracy: 0.3846 - 9s/epoch - 141ms/step
# Epoch 47/50
# 63/63 - 9s - loss: 0.4950 - accuracy: 0.8196 - val_loss: 2.1391 - val_accuracy: 0.3846 - 9s/epoch - 141ms/step
# Epoch 48/50
# 63/63 - 9s - loss: 0.3891 - accuracy: 0.8617 - val_loss: 1.6804 - val_accuracy: 0.4615 - 9s/epoch - 141ms/step
# Epoch 49/50
# 63/63 - 9s - loss: 0.4393 - accuracy: 0.8216 - val_loss: 1.6486 - val_accuracy: 0.5192 - 9s/epoch - 141ms/step
# Epoch 50/50
# 63/63 - 9s - loss: 0.3983 - accuracy: 0.8437 - val_loss: 2.0285 - val_accuracy: 0.4615 - 9s/epoch - 140ms/step

# %%
#Anda juga dapat membuat plot akurasi dari model menggunakan kode berikut.
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
